# %% [markdown]
# <a href="https://colab.research.google.com/github/Fajardo47/Cpen_21-BS-EcE-2-3/blob/main/Demo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Python Indention

# %%
if 5>2:
  print ("Five is greater than two") #This code shows a string of a words
# Out:
# Five is greater than two

# %% [markdown]
# ##Python Variable

# %%
a,b,c=0,1,2
d ="Sally"  #This is a type of string
s= 'mark'  #This is a type of string
A= 'Raymond'
print(a)
print(b)
print(c)
print(d)
print(A)
# Out:
# 0
# 1
# 2
# Sally
# Raymond

# %% [markdown]
# ###Casting

# %%
print(float(4.5))
f =56.47
print(type(f))
# Out:
# 4.5
# <class 'float'>

# %%
x,y,z="one","two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %%
x=y=z="four"  #Multiple variable but single values
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %%
x= "enjoying"
print("Python programming is "+x)
# Out:
# Python programming is enjoying

# %% [markdown]
# ##Operations in Python

# %%
k=10
l=5
print(k+l)
# Out:
# 15

# %%
k+=l     #Is the same as k=k+l
print(k)
# Out:
# 15

# %%
not (k>1 or k==l)
# Out:
# False

# %%
not (k is l)
k is not l
# Out:
# True

# %%
k%=3
k
# Out:
# 0
